# %%
print("Hello, Complaint AI!")
# Out:
# Hello, Complaint AI!

# %%
def classify_complaint(complaint: str):
    """
    Mock AI classifier using keyword matching.
    Returns category and priority.
    """

    text = complaint.lower()

    # Determine Category
    if any(word in text for word in [
        "payment",
        "refund",
        "charged",
        "billing",
        "invoice",
        "deducted",
        "transaction"
    ]):
        category = "Billing"

    elif any(word in text for word in [
        "bug",
        "error",
        "crash",
        "technical",
        "loading",
        "failed"
    ]):
        category = "Technical"

    elif any(word in text for word in [
        "hack",
        "hacked",
        "unauthorized",
        "password",
        "breach",
        "security",
        "suspicious"
    ]):
        category = "Security"

    else:
        category = "Account"

    # Determine Priority
    if any(word in text for word in [
        "urgent",
        "immediately",
        "critical",
        "hack",
        "hacked",
        "breach",
        "unauthorized"
    ]):
        priority = "Critical"

    elif any(word in text for word in [
        "refund",
        "deducted",
        "charged",
        "cannot",
        "can't",
        "unable"
    ]):
        priority = "High"

    elif any(word in text for word in [
        "issue",
        "problem",
        "delay"
    ]):
        priority = "Medium"

    else:
        priority = "Low"

    return {
        "category": category,
        "priority": priority
    }

# %%
classify_complaint(
    "My payment was deducted twice and I have not received a refund."
)
# Out:
# {'category': 'Billing', 'priority': 'High'}

# %%
classify_complaint(
    "The application crashes whenever I upload a file."
)
# Out:
# {'category': 'Technical', 'priority': 'Low'}

# %%
def classify_complaint(complaint: str):
    """
    Mock AI classifier using keyword matching.
    Returns category and priority.
    """

    text = complaint.lower()

    # Determine Category
    if any(word in text for word in [
        "payment",
        "refund",
        "charged",
        "billing",
        "invoice",
        "deducted",
        "transaction"
    ]):
        category = "Billing"

    elif any(word in text for word in [
        "bug",
        "error",
        "crash",
        "technical",
        "loading",
        "failed"
    ]):
        category = "Technical"

    elif any(word in text for word in [
        "hack",
        "hacked",
        "unauthorized",
        "password",
        "breach",
        "security",
        "suspicious"
    ]):
        category = "Security"

    else:
        category = "Account"

    # Determine Priority
    if any(word in text for word in [
        "urgent",
        "immediately",
        "critical",
        "hack",
        "hacked",
        "breach",
        "unauthorized"
    ]):
        priority = "Critical"

    elif any(word in text for word in [
        "refund",
        "deducted",
        "charged",
        "cannot",
        "can't",
        "unable"
    ]):
        priority = "High"

    elif any(word in text for word in [
    "issue",
    "problem",
    "delay",
    "crash",
    "error",
    "failed"
]):
    priority = "Medium"

    else:
        priority = "Low"

    return {
        "category": category,
        "priority": priority
    }
# Out:
#   Cell In[5], line 75
#     priority = "Medium"
#     ^
# IndentationError: expected an indented block after 'elif' statement on line 67

# %%
def classify_complaint(complaint: str):
    """
    Mock AI classifier using keyword matching.
    Returns category and priority.
    """

    text = complaint.lower()

    # Determine Category
    if any(word in text for word in [
        "payment",
        "refund",
        "charged",
        "billing",
        "invoice",
        "deducted",
        "transaction"
    ]):
        category = "Billing"

    elif any(word in text for word in [
        "bug",
        "error",
        "crash",
        "technical",
        "loading",
        "failed"
    ]):
        category = "Technical"

    elif any(word in text for word in [
        "hack",
        "hacked",
        "unauthorized",
        "password",
        "breach",
        "security",
        "suspicious"
    ]):
        category = "Security"

    else:
        category = "Account"

    # Determine Priority
    if any(word in text for word in [
        "urgent",
        "immediately",
        "critical",
        "hack",
        "hacked",
        "breach",
        "unauthorized"
    ]):
        priority = "Critical"

    elif any(word in text for word in [
        "refund",
        "deducted",
        "charged",
        "cannot",
        "can't",
        "unable"
    ]):
        priority = "High"

    elif any(word in text for word in [
   	"issue",
    	"problem",
    	"delay",
    	"crash",
    	"error",
    	"failed"
]):
    priority = "Medium"

    else:
        priority = "Low"

    return {
        "category": category,
        "priority": priority
    }
# Out:
#   Cell In[6], line 75
#     priority = "Medium"
#     ^
# IndentationError: expected an indented block after 'elif' statement on line 67

# %%
def classify_complaint(complaint: str):
    """
    Mock AI classifier using keyword matching.
    Returns category and priority.
    """

    text = complaint.lower()

    # Determine Category
    if any(word in text for word in [
        "payment",
        "refund",
        "charged",
        "billing",
        "invoice",
        "deducted",
        "transaction"
    ]):
        category = "Billing"

    elif any(word in text for word in [
        "bug",
        "error",
        "crash",
        "technical",
        "loading",
        "failed"
    ]):
        category = "Technical"

    elif any(word in text for word in [
        "hack",
        "hacked",
        "unauthorized",
        "password",
        "breach",
        "security",
        "suspicious"
    ]):
        category = "Security"

    else:
        category = "Account"

    # Determine Priority
    if any(word in text for word in [
        "urgent",
        "immediately",
        "critical",
        "hack",
        "hacked",
        "breach",
        "unauthorized"
    ]):
        priority = "Critical"

    elif any(word in text for word in [
        "refund",
        "deducted",
        "charged",
        "cannot",
        "can't",
        "unable"
    ]):
        priority = "High"

    elif any(word in text for word in [
        "issue",
        "problem",
        "delay",
        "crash",
        "error",
        "failed"
    ]):
        priority = "Medium"

    else:
        priority = "Low"

    return {
        "category": category,
        "priority": priority
    }

# %%
classify_complaint(
    "My payment was deducted twice and I have not received a refund."
)
# Out:
# {'category': 'Billing', 'priority': 'High'}

# %%
classify_complaint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 classify_complaint()
#
# TypeError: classify_complaint() missing 1 required positional argument: 'complaint'

# %%
classify_complaint(
    "My payment was deducted twice and I have not received a refund."
)
# Out:
# {'category': 'Billing', 'priority': 'High'}

# %%
TEAM_MAP = {
    "Billing": "Finance Team",
    "Technical": "Engineering Team",
    "Account": "Customer Support",
    "Security": "Security Team"
}

def assign_team(category):
    return TEAM_MAP.get(category, "Customer Support")

# %%
assign_team("Billing")
# Out:
# 'Finance Team'

# %%
assign_team("Billing")
# Out:
# 'Finance Team'

# %%
assign_team("Security")
# Out:
# 'Security Team'

# %%
def process_complaint(complaint):
    result = classify_complaint(complaint)

    team = assign_team(result["category"])

    return {
        "complaint": complaint,
        "category": result["category"],
        "priority": result["priority"],
        "team": team
    }

# %%
process_complaint(
    "My payment was deducted twice and I have not received a refund."
)
# Out:
# {'complaint': 'My payment was deducted twice and I have not received a refund.',
#  'category': 'Billing',
#  'priority': 'High',
#  'team': 'Finance Team'}

# %%
TEAM_MAP = {
    "Billing": "Finance Team",
    "Technical": "Engineering Team",
    "Account": "Customer Support",
    "Security": "Security Team"
}

def assign_team(category):
    return TEAM_MAP.get(category, "Customer Support")

# %%
def process_complaint(complaint):
    result = classify_complaint(complaint)

    team = assign_team(result["category"])

    return {
        "complaint": complaint,
        "category": result["category"],
        "priority": result["priority"],
        "team": team
    }

# %%
process_complaint(
    "My payment was deducted twice and I have not received a refund."
)
# Out:
# {'complaint': 'My payment was deducted twice and I have not received a refund.',
#  'category': 'Billing',
#  'priority': 'High',
#  'team': 'Finance Team'}

# %%
sample_complaints = [
    "My payment was deducted twice and I have not received a refund.",
    "Someone hacked my account and changed my password.",
    "The application crashes whenever I upload a file.",
    "I cannot access my account after updating my email.",
    "There is a bug preventing me from submitting forms.",
    "Unauthorized login detected on my account.",
    "Please help me update my account details."
]

# %%
processed_complaints = []

for complaint in sample_complaints:
    result = process_complaint(complaint)
    processed_complaints.append(result)

processed_complaints
# Out:
# [{'complaint': 'My payment was deducted twice and I have not received a refund.',
#   'category': 'Billing',
#   'priority': 'High',
#   'team': 'Finance Team'},
#  {'complaint': 'Someone hacked my account and changed my password.',
#   'category': 'Security',
#   'priority': 'Critical',
#   'team': 'Security Team'},
#  {'complaint': 'The application crashes whenever I upload a file.',
#   'category': 'Technical',
#   'priority': 'Medium',
#   'team': 'Engineering Team'},
#  {'complaint': 'I cannot access my account after updating my email.',
#   'category': 'Account',
#   'priority': 'High',
#   'team': 'Customer Support'},
#  {'complaint': 'There is a bug preventing me from submitting forms.',
#   'category': 'Technical',
#   'priority': 'Low',
#   'team': 'Engineering Team'},
#  {'complaint': 'Unauthorized login detected on my account.',
#   'category': 'Security',
#   'priority': 'Critical',
#   'team': 'Security Team'},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(processed_complaints)
df
# Out:
#                                            complaint   category  priority  \
# 0  My payment was deducted twice and I have not r...    Billing      High
# 1  Someone hacked my account and changed my passw...   Security  Critical
# 2  The application crashes whenever I upload a file.  Technical    Medium
# 3  I cannot access my account after updating my e...    Account      High
# 4  There is a bug preventing me from submitting f...  Technical       Low
# 5         Unauthorized login detected on my account.   Security  Critical
# 6          Please help me update my account details.    Account       Low
#
#                team
# 0      Finance Team
# 1     Security Team
# 2  Engineering Team
# 3  Customer Support
# 4  Engineering Team
# 5     Security Team
# 6  Customer Support

# %%
sample_complaints = [...]

# %%
processed_complaints = []

for complaint in sample_complaints:
    result = process_complaint(complaint)
    processed_complaints.append(result)

processed_complaints
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 4
#       1 processed_complaints = []
#       2
#       3 for complaint in sample_complaints:
# ----> 4     result = process_complaint(complaint)
#       5     processed_complaints.append(result)
#       6
#       7 processed_complaints
#
# Cell In[18], line 2, in process_complaint(complaint)
#       1 def process_complaint(complaint):
# ----> 2     result = classify_complaint(complaint)
#       3
#       4     team = assign_team(result["category"])
#       5
#
# Cell In[7], line 7, in classify_complaint(complaint)
#       3     Mock AI classifier using keyword matching.
#       4     Returns category and priority.
#       5     """
#       6
# ----> 7     text = complaint.lower()
#       8
#       9     # Determine Category
#      10     if any(word in text for word in [
#
# ...

# %%
sample_complaints = [
    "My payment was deducted twice and I have not received a refund.",
    "Someone hacked my account and changed my password.",
    "The application crashes whenever I upload a file.",
    "I cannot access my account after updating my email.",
    "There is a bug preventing me from submitting forms.",
    "Unauthorized login detected on my account.",
    "Please help me update my account details."
]

# %%
sample_complaints
# Out:
# ['My payment was deducted twice and I have not received a refund.',
#  'Someone hacked my account and changed my password.',
#  'The application crashes whenever I upload a file.',
#  'I cannot access my account after updating my email.',
#  'There is a bug preventing me from submitting forms.',
#  'Unauthorized login detected on my account.',
#  'Please help me update my account details.']

# %%
processed_complaints = []

for complaint in sample_complaints:
    result = process_complaint(complaint)
    processed_complaints.append(result)

processed_complaints
# Out:
# [{'complaint': 'My payment was deducted twice and I have not received a refund.',
#   'category': 'Billing',
#   'priority': 'High',
#   'team': 'Finance Team'},
#  {'complaint': 'Someone hacked my account and changed my password.',
#   'category': 'Security',
#   'priority': 'Critical',
#   'team': 'Security Team'},
#  {'complaint': 'The application crashes whenever I upload a file.',
#   'category': 'Technical',
#   'priority': 'Medium',
#   'team': 'Engineering Team'},
#  {'complaint': 'I cannot access my account after updating my email.',
#   'category': 'Account',
#   'priority': 'High',
#   'team': 'Customer Support'},
#  {'complaint': 'There is a bug preventing me from submitting forms.',
#   'category': 'Technical',
#   'priority': 'Low',
#   'team': 'Engineering Team'},
#  {'complaint': 'Unauthorized login detected on my account.',
#   'category': 'Security',
#   'priority': 'Critical',
#   'team': 'Security Team'},
# ...

# %%
type(sample_complaints[0])
# Out:
# str

# %%
type(sample_complaints[0])
# Out:
# str

# %%
import pandas as pd

# %%
df = pd.DataFrame(processed_complaints)
df
# Out:
#                                            complaint   category  priority  \
# 0  My payment was deducted twice and I have not r...    Billing      High
# 1  Someone hacked my account and changed my passw...   Security  Critical
# 2  The application crashes whenever I upload a file.  Technical    Medium
# 3  I cannot access my account after updating my e...    Account      High
# 4  There is a bug preventing me from submitting f...  Technical       Low
# 5         Unauthorized login detected on my account.   Security  Critical
# 6          Please help me update my account details.    Account       Low
#
#                team
# 0      Finance Team
# 1     Security Team
# 2  Engineering Team
# 3  Customer Support
# 4  Engineering Team
# 5     Security Team
# 6  Customer Support

# %%
len(df)
# Out:
# 7

# %%
df["category"].value_counts()
# Out:
# category
# Security     2
# Technical    2
# Account      2
# Billing      1
# Name: count, dtype: int64

# %%
df["priority"].value_counts()
# Out:
# priority
# High        2
# Critical    2
# Low         2
# Medium      1
# Name: count, dtype: int64

# %%
df["team"].value_counts()
# Out:
# team
# Security Team       2
# Engineering Team    2
# Customer Support    2
# Finance Team        1
# Name: count, dtype: int64

# %%
df.to_csv("complaint_results.csv", index=False)

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.ipython',
#  '.python_history',
#  '.vscode',
#  '.vscode-shared',
#  'AppData',
#  'Application Data',
#  'complaint_results.csv',
#  'complaint_testing.ipynb',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{c0ca5695-8027-11f0-a973-8fc0f57c4c46}.TM.blf',
#  'NTUSER.DAT{c0ca5695-8027-11f0-a973-8fc0f57c4c46}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{c0ca5695-8027-11f0-a973-8fc0f57c4c46}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'venv',
#  'Videos']

# %%
len(df)
# Out:
# 7

# %%
df["category"].value_counts()
# Out:
# category
# Security     2
# Technical    2
# Account      2
# Billing      1
# Name: count, dtype: int64

# %%
df["priority"].value_counts()
# Out:
# priority
# High        2
# Critical    2
# Low         2
# Medium      1
# Name: count, dtype: int64

# %%
from processor import process_complaints
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 from processor import process_complaints
#
# ModuleNotFoundError: No module named 'processor'
